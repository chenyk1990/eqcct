# %%
from mseed_predictor import *
import os

json_basepath = os.path.join(os.getcwd(),"station_list.json")

mseed_predictor(input_dir=r'./Japan_MSEED/',   
         input_model='ModelP/test_trainer_016.h5',
         stations_json=json_basepath,
         output_dir='detections2',
         P_threshold=0.1,
         S_threshold=0.1, 
         number_of_plots=10,
         normalization_mode='std',
         batch_size=1,
         overlap=0.8,
         gpuid=None,
         gpu_limit=None)
# Out:
# 09-16 18:16 [INFO] [EQCCT_Picker] Running EQCCT_Picker
# 09-16 18:16 [INFO] [EQCCT_Picker] *** Loading the model ...
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input (InputLayer)             [(None, 6000, 3)]    0           []
#
#  conv1d_66 (Conv1D)             (None, 6000, 3)      102         ['input[0][0]']
#
#  conv1d_99 (Conv1D)             (None, 6000, 3)      102         ['input[0][0]']
#
#  batch_normalization_66 (BatchN  (None, 6000, 3)     12          ['conv1d_66[0][0]']
#  ormalization)
#
#  batch_normalization_99 (BatchN  (None, 6000, 3)     12          ['conv1d_99[0][0]']
#  ormalization)
#
#  activation_66 (Activation)     (None, 6000, 3)      0           ['batch_normalization_66[0][0]']
#
#  activation_99 (Activation)     (None, 6000, 3)      0           ['batch_normalization_99[0][0]']
#
#  conv1d_67 (Conv1D)             (None, 6000, 3)      102         ['activation_66[0][0]']
#
#  conv1d_100 (Conv1D)            (None, 6000, 3)      102         ['activation_99[0][0]']
#
#  batch_normalization_67 (BatchN  (None, 6000, 3)     12          ['conv1d_67[0][0]']
#  ormalization)
#
#  batch_normalization_100 (Batch  (None, 6000, 3)     12          ['conv1d_100[0][0]']
#  Normalization)
#
#  activation_67 (Activation)     (None, 6000, 3)      0           ['batch_normalization_67[0][0]']
#
#  activation_100 (Activation)    (None, 6000, 3)      0           ['batch_normalization_100[0][0]']
#
#  add_38 (Add)                   (None, 6000, 3)      0           ['activation_67[0][0]',
#                                                                   'input[0][0]']
#
#  add_57 (Add)                   (None, 6000, 3)      0           ['activation_100[0][0]',
#                                                                   'input[0][0]']
#
#  conv1d_68 (Conv1D)             (None, 6000, 10)     340         ['add_38[0][0]']
#
#  conv1d_101 (Conv1D)            (None, 6000, 10)     340         ['add_57[0][0]']
#
#  batch_normalization_68 (BatchN  (None, 6000, 10)    40          ['conv1d_68[0][0]']
#  ormalization)
#
#  batch_normalization_101 (Batch  (None, 6000, 10)    40          ['conv1d_101[0][0]']
#  Normalization)
#
#  activation_68 (Activation)     (None, 6000, 10)     0           ['batch_normalization_68[0][0]']
#
#  activation_101 (Activation)    (None, 6000, 10)     0           ['batch_normalization_101[0][0]']
#
#  dropout_38 (Dropout)           (None, 6000, 10)     0           ['activation_68[0][0]']
#
#  dropout_57 (Dropout)           (None, 6000, 10)     0           ['activation_101[0][0]']
#
#  conv1d_69 (Conv1D)             (None, 6000, 10)     1110        ['dropout_38[0][0]']
#
#  conv1d_102 (Conv1D)            (None, 6000, 10)     1110        ['dropout_57[0][0]']
#
#  batch_normalization_69 (BatchN  (None, 6000, 10)    40          ['conv1d_69[0][0]']
#  ormalization)
#
#  batch_normalization_102 (Batch  (None, 6000, 10)    40          ['conv1d_102[0][0]']
#  Normalization)
#
#  activation_69 (Activation)     (None, 6000, 10)     0           ['batch_normalization_69[0][0]']
#
#  activation_102 (Activation)    (None, 6000, 10)     0           ['batch_normalization_102[0][0]']
#
#  conv1d_70 (Conv1D)             (None, 6000, 10)     1110        ['activation_69[0][0]']
#
#  conv1d_103 (Conv1D)            (None, 6000, 10)     1110        ['activation_102[0][0]']
#
#  batch_normalization_70 (BatchN  (None, 6000, 10)    40          ['conv1d_70[0][0]']
#  ormalization)
#
#  batch_normalization_103 (Batch  (None, 6000, 10)    40          ['conv1d_103[0][0]']
#  Normalization)
#
#  activation_70 (Activation)     (None, 6000, 10)     0           ['batch_normalization_70[0][0]']
#  activation_103 (Activation)    (None, 6000, 10)     0           ['batch_normalization_103[0][0]']
#
#  add_39 (Add)                   (None, 6000, 10)     0           ['activation_70[0][0]',
#                                                                   'dropout_38[0][0]']
#
#  add_58 (Add)                   (None, 6000, 10)     0           ['activation_103[0][0]',
#                                                                   'dropout_57[0][0]']
#
#  conv1d_71 (Conv1D)             (None, 6000, 20)     2220        ['add_39[0][0]']
#
#  conv1d_104 (Conv1D)            (None, 6000, 20)     2220        ['add_58[0][0]']
#
#  batch_normalization_71 (BatchN  (None, 6000, 20)    80          ['conv1d_71[0][0]']
#  ormalization)
#
#  batch_normalization_104 (Batch  (None, 6000, 20)    80          ['conv1d_104[0][0]']
#  Normalization)
#
#  activation_71 (Activation)     (None, 6000, 20)     0           ['batch_normalization_71[0][0]']
#
#  activation_104 (Activation)    (None, 6000, 20)     0           ['batch_normalization_104[0][0]']
#
#  dropout_39 (Dropout)           (None, 6000, 20)     0           ['activation_71[0][0]']
#
#  dropout_58 (Dropout)           (None, 6000, 20)     0           ['activation_104[0][0]']
#
#  conv1d_72 (Conv1D)             (None, 6000, 20)     4420        ['dropout_39[0][0]']
#
#  conv1d_105 (Conv1D)            (None, 6000, 20)     4420        ['dropout_58[0][0]']
#
#  batch_normalization_72 (BatchN  (None, 6000, 20)    80          ['conv1d_72[0][0]']
#  ormalization)
#
#  batch_normalization_105 (Batch  (None, 6000, 20)    80          ['conv1d_105[0][0]']
#  Normalization)
#
#  activation_72 (Activation)     (None, 6000, 20)     0           ['batch_normalization_72[0][0]']
#
#  activation_105 (Activation)    (None, 6000, 20)     0           ['batch_normalization_105[0][0]']
#
#  conv1d_73 (Conv1D)             (None, 6000, 20)     4420        ['activation_72[0][0]']
#
#  conv1d_106 (Conv1D)            (None, 6000, 20)     4420        ['activation_105[0][0]']
#
#  batch_normalization_73 (BatchN  (None, 6000, 20)    80          ['conv1d_73[0][0]']
#  ormalization)
#
#  batch_normalization_106 (Batch  (None, 6000, 20)    80          ['conv1d_106[0][0]']
#  Normalization)
#
#  activation_73 (Activation)     (None, 6000, 20)     0           ['batch_normalization_73[0][0]']
#
#  activation_106 (Activation)    (None, 6000, 20)     0           ['batch_normalization_106[0][0]']
#
#  add_40 (Add)                   (None, 6000, 20)     0           ['activation_73[0][0]',
#                                                                   'dropout_39[0][0]']
#
#  add_59 (Add)                   (None, 6000, 20)     0           ['activation_106[0][0]',
#                                                                   'dropout_58[0][0]']
#
#  conv1d_74 (Conv1D)             (None, 6000, 40)     8840        ['add_40[0][0]']
#
#  conv1d_107 (Conv1D)            (None, 6000, 40)     8840        ['add_59[0][0]']
#
#  batch_normalization_74 (BatchN  (None, 6000, 40)    160         ['conv1d_74[0][0]']
#  ormalization)
#
#  batch_normalization_107 (Batch  (None, 6000, 40)    160         ['conv1d_107[0][0]']
#  Normalization)
#
#  activation_74 (Activation)     (None, 6000, 40)     0           ['batch_normalization_74[0][0]']
#
#  activation_107 (Activation)    (None, 6000, 40)     0           ['batch_normalization_107[0][0]']
#
#  dropout_40 (Dropout)           (None, 6000, 40)     0           ['activation_74[0][0]']
#
#  dropout_59 (Dropout)           (None, 6000, 40)     0           ['activation_107[0][0]']
#
#  reshape_4 (Reshape)            (None, 6000, 1, 40)  0           ['dropout_40[0][0]']
#
#  reshape_6 (Reshape)            (None, 6000, 1, 40)  0           ['dropout_59[0][0]']
#
#  patches_2 (Patches)            (None, None, 1600)   0           ['reshape_4[0][0]']
#
#  patches_3 (Patches)            (None, None, 1600)   0           ['reshape_6[0][0]']
#
#  patch_encoder_2 (PatchEncoder)  (None, 150, 40)     70040       ['patches_2[0][0]']
#
#  patch_encoder_3 (PatchEncoder)  (None, 150, 40)     70040       ['patches_3[0][0]']
#
#  conv1d_75 (Conv1D)             (None, 150, 40)      17640       ['patch_encoder_2[0][0]']
#
#  conv1d_108 (Conv1D)            (None, 150, 40)      17640       ['patch_encoder_3[0][0]']
#
#  batch_normalization_75 (BatchN  (None, 150, 40)     160         ['conv1d_75[0][0]']
#  ormalization)
#
#  batch_normalization_108 (Batch  (None, 150, 40)     160         ['conv1d_108[0][0]']
#  Normalization)
#
#  activation_75 (Activation)     (None, 150, 40)      0           ['batch_normalization_75[0][0]']
#
#  activation_108 (Activation)    (None, 150, 40)      0           ['batch_normalization_108[0][0]']
#
#  conv1d_76 (Conv1D)             (None, 150, 40)      17640       ['activation_75[0][0]']
#
#  conv1d_109 (Conv1D)            (None, 150, 40)      17640       ['activation_108[0][0]']
#
#  batch_normalization_76 (BatchN  (None, 150, 40)     160         ['conv1d_76[0][0]']
#  ormalization)
#
#  batch_normalization_109 (Batch  (None, 150, 40)     160         ['conv1d_109[0][0]']
#  Normalization)
#
#  activation_76 (Activation)     (None, 150, 40)      0           ['batch_normalization_76[0][0]']
#
#  activation_109 (Activation)    (None, 150, 40)      0           ['batch_normalization_109[0][0]']
#
#  add_41 (Add)                   (None, 150, 40)      0           ['activation_76[0][0]',
#                                                                   'patch_encoder_2[0][0]']
#
#  add_60 (Add)                   (None, 150, 40)      0           ['activation_109[0][0]',
#                                                                   'patch_encoder_3[0][0]']
#
#  conv1d_77 (Conv1D)             (None, 150, 40)      17640       ['add_41[0][0]']
#
#  conv1d_110 (Conv1D)            (None, 150, 40)      17640       ['add_60[0][0]']
#
#  batch_normalization_77 (BatchN  (None, 150, 40)     160         ['conv1d_77[0][0]']
#  ormalization)
#
#  batch_normalization_110 (Batch  (None, 150, 40)     160         ['conv1d_110[0][0]']
#  Normalization)
#
#  activation_77 (Activation)     (None, 150, 40)      0           ['batch_normalization_77[0][0]']
#
#  activation_110 (Activation)    (None, 150, 40)      0           ['batch_normalization_110[0][0]']
#
#  dropout_41 (Dropout)           (None, 150, 40)      0           ['activation_77[0][0]']
#
#  dropout_60 (Dropout)           (None, 150, 40)      0           ['activation_110[0][0]']
#
#  layer_normalization_18 (LayerN  (None, 150, 40)     80          ['dropout_41[0][0]']
#  ormalization)
#
#  layer_normalization_27 (LayerN  (None, 150, 40)     80          ['dropout_60[0][0]']
#  ormalization)
#
#  multi_head_attention_8 (MultiH  (None, 150, 40)     26120       ['layer_normalization_18[0][0]',
#  eadAttention)                                                    'layer_normalization_18[0][0]']
#
#  multi_head_attention_12 (Multi  (None, 150, 40)     26120       ['layer_normalization_27[0][0]',
#  HeadAttention)                                                   'layer_normalization_27[0][0]']
#
#  conv1d_78 (Conv1D)             (None, 150, 40)      17640       ['multi_head_attention_8[0][0]']
#
#  conv1d_111 (Conv1D)            (None, 150, 40)      17640       ['multi_head_attention_12[0][0]']
#
#  batch_normalization_78 (BatchN  (None, 150, 40)     160         ['conv1d_78[0][0]']
#  ormalization)
#
#  batch_normalization_111 (Batch  (None, 150, 40)     160         ['conv1d_111[0][0]']
#  Normalization)
#
#  activation_78 (Activation)     (None, 150, 40)      0           ['batch_normalization_78[0][0]']
#  activation_111 (Activation)    (None, 150, 40)      0           ['batch_normalization_111[0][0]']
#
#  conv1d_79 (Conv1D)             (None, 150, 40)      17640       ['activation_78[0][0]']
#
#  conv1d_112 (Conv1D)            (None, 150, 40)      17640       ['activation_111[0][0]']
#
#  batch_normalization_79 (BatchN  (None, 150, 40)     160         ['conv1d_79[0][0]']
#  ormalization)
#
#  batch_normalization_112 (Batch  (None, 150, 40)     160         ['conv1d_112[0][0]']
#  Normalization)
#
#  activation_79 (Activation)     (None, 150, 40)      0           ['batch_normalization_79[0][0]']
#
#  activation_112 (Activation)    (None, 150, 40)      0           ['batch_normalization_112[0][0]']
#
#  add_42 (Add)                   (None, 150, 40)      0           ['activation_79[0][0]',
#                                                                   'multi_head_attention_8[0][0]']
#
#  add_61 (Add)                   (None, 150, 40)      0           ['activation_112[0][0]',
#                                                                   'multi_head_attention_12[0][0]']
#
#  conv1d_80 (Conv1D)             (None, 150, 40)      17640       ['add_42[0][0]']
#
#  conv1d_113 (Conv1D)            (None, 150, 40)      17640       ['add_61[0][0]']
#
#  batch_normalization_80 (BatchN  (None, 150, 40)     160         ['conv1d_80[0][0]']
#  ormalization)
#
#  batch_normalization_113 (Batch  (None, 150, 40)     160         ['conv1d_113[0][0]']
#  Normalization)
#
#  activation_80 (Activation)     (None, 150, 40)      0           ['batch_normalization_80[0][0]']
#
#  activation_113 (Activation)    (None, 150, 40)      0           ['batch_normalization_113[0][0]']
#
#  dropout_42 (Dropout)           (None, 150, 40)      0           ['activation_80[0][0]']
#
#  dropout_61 (Dropout)           (None, 150, 40)      0           ['activation_113[0][0]']
#
#  stochastic_depth_16 (Stochasti  (None, 150, 40)     0           ['dropout_42[0][0]']
#  cDepth)
#
#  stochastic_depth_24 (Stochasti  (None, 150, 40)     0           ['dropout_61[0][0]']
#  cDepth)
#
#  add_43 (Add)                   (None, 150, 40)      0           ['stochastic_depth_16[0][0]',
#                                                                   'dropout_41[0][0]']
#
#  add_62 (Add)                   (None, 150, 40)      0           ['stochastic_depth_24[0][0]',
#                                                                   'dropout_60[0][0]']
#
#  layer_normalization_19 (LayerN  (None, 150, 40)     80          ['add_43[0][0]']
#  ormalization)
#
#  layer_normalization_28 (LayerN  (None, 150, 40)     80          ['add_62[0][0]']
#  ormalization)
#
#  dense_19 (Dense)               (None, 150, 40)      1640        ['layer_normalization_19[0][0]']
#
#  dense_28 (Dense)               (None, 150, 40)      1640        ['layer_normalization_28[0][0]']
#
#  dropout_43 (Dropout)           (None, 150, 40)      0           ['dense_19[0][0]']
#
#  dropout_62 (Dropout)           (None, 150, 40)      0           ['dense_28[0][0]']
#
#  dense_20 (Dense)               (None, 150, 40)      1640        ['dropout_43[0][0]']
#
#  dense_29 (Dense)               (None, 150, 40)      1640        ['dropout_62[0][0]']
#
#  dropout_44 (Dropout)           (None, 150, 40)      0           ['dense_20[0][0]']
#
#  dropout_63 (Dropout)           (None, 150, 40)      0           ['dense_29[0][0]']
#
#  stochastic_depth_17 (Stochasti  (None, 150, 40)     0           ['dropout_44[0][0]']
#  cDepth)
#
#  stochastic_depth_25 (Stochasti  (None, 150, 40)     0           ['dropout_63[0][0]']
#  cDepth)
#
#  add_44 (Add)                   (None, 150, 40)      0           ['stochastic_depth_17[0][0]',
#                                                                   'add_43[0][0]']
#  add_63 (Add)                   (None, 150, 40)      0           ['stochastic_depth_25[0][0]',
#                                                                   'add_62[0][0]']
#
#  conv1d_81 (Conv1D)             (None, 150, 40)      17640       ['add_44[0][0]']
#
#  conv1d_114 (Conv1D)            (None, 150, 40)      17640       ['add_63[0][0]']
#
#  batch_normalization_81 (BatchN  (None, 150, 40)     160         ['conv1d_81[0][0]']
#  ormalization)
#
#  batch_normalization_114 (Batch  (None, 150, 40)     160         ['conv1d_114[0][0]']
#  Normalization)
#
#  activation_81 (Activation)     (None, 150, 40)      0           ['batch_normalization_81[0][0]']
#
#  activation_114 (Activation)    (None, 150, 40)      0           ['batch_normalization_114[0][0]']
#
#  conv1d_82 (Conv1D)             (None, 150, 40)      17640       ['activation_81[0][0]']
#
#  conv1d_115 (Conv1D)            (None, 150, 40)      17640       ['activation_114[0][0]']
#
#  batch_normalization_82 (BatchN  (None, 150, 40)     160         ['conv1d_82[0][0]']
#  ormalization)
#
#  batch_normalization_115 (Batch  (None, 150, 40)     160         ['conv1d_115[0][0]']
#  Normalization)
#
#  activation_82 (Activation)     (None, 150, 40)      0           ['batch_normalization_82[0][0]']
#
#  activation_115 (Activation)    (None, 150, 40)      0           ['batch_normalization_115[0][0]']
#
#  add_45 (Add)                   (None, 150, 40)      0           ['activation_82[0][0]',
#                                                                   'add_44[0][0]']
#
#  add_64 (Add)                   (None, 150, 40)      0           ['activation_115[0][0]',
#                                                                   'add_63[0][0]']
#
#  conv1d_83 (Conv1D)             (None, 150, 40)      17640       ['add_45[0][0]']
#
#  conv1d_116 (Conv1D)            (None, 150, 40)      17640       ['add_64[0][0]']
#
#  batch_normalization_83 (BatchN  (None, 150, 40)     160         ['conv1d_83[0][0]']
#  ormalization)
#
#  batch_normalization_116 (Batch  (None, 150, 40)     160         ['conv1d_116[0][0]']
#  Normalization)
#
#  activation_83 (Activation)     (None, 150, 40)      0           ['batch_normalization_83[0][0]']
#
#  activation_116 (Activation)    (None, 150, 40)      0           ['batch_normalization_116[0][0]']
#
#  dropout_45 (Dropout)           (None, 150, 40)      0           ['activation_83[0][0]']
#
#  dropout_64 (Dropout)           (None, 150, 40)      0           ['activation_116[0][0]']
#
#  layer_normalization_20 (LayerN  (None, 150, 40)     80          ['dropout_45[0][0]']
#  ormalization)
#
#  layer_normalization_29 (LayerN  (None, 150, 40)     80          ['dropout_64[0][0]']
#  ormalization)
#
#  multi_head_attention_9 (MultiH  (None, 150, 40)     26120       ['layer_normalization_20[0][0]',
#  eadAttention)                                                    'layer_normalization_20[0][0]']
#
#  multi_head_attention_13 (Multi  (None, 150, 40)     26120       ['layer_normalization_29[0][0]',
#  HeadAttention)                                                   'layer_normalization_29[0][0]']
#
#  conv1d_84 (Conv1D)             (None, 150, 40)      17640       ['multi_head_attention_9[0][0]']
#
#  conv1d_117 (Conv1D)            (None, 150, 40)      17640       ['multi_head_attention_13[0][0]']
#
#  batch_normalization_84 (BatchN  (None, 150, 40)     160         ['conv1d_84[0][0]']
#  ormalization)
#
#  batch_normalization_117 (Batch  (None, 150, 40)     160         ['conv1d_117[0][0]']
#  Normalization)
#
#  activation_84 (Activation)     (None, 150, 40)      0           ['batch_normalization_84[0][0]']
#
#  activation_117 (Activation)    (None, 150, 40)      0           ['batch_normalization_117[0][0]']
#
#  conv1d_85 (Conv1D)             (None, 150, 40)      17640       ['activation_84[0][0]']
#  conv1d_118 (Conv1D)            (None, 150, 40)      17640       ['activation_117[0][0]']
#
#  batch_normalization_85 (BatchN  (None, 150, 40)     160         ['conv1d_85[0][0]']
#  ormalization)
#
#  batch_normalization_118 (Batch  (None, 150, 40)     160         ['conv1d_118[0][0]']
#  Normalization)
#
#  activation_85 (Activation)     (None, 150, 40)      0           ['batch_normalization_85[0][0]']
#
#  activation_118 (Activation)    (None, 150, 40)      0           ['batch_normalization_118[0][0]']
#
#  add_46 (Add)                   (None, 150, 40)      0           ['activation_85[0][0]',
#                                                                   'multi_head_attention_9[0][0]']
#
#  add_65 (Add)                   (None, 150, 40)      0           ['activation_118[0][0]',
#                                                                   'multi_head_attention_13[0][0]']
#
#  conv1d_86 (Conv1D)             (None, 150, 40)      17640       ['add_46[0][0]']
#
#  conv1d_119 (Conv1D)            (None, 150, 40)      17640       ['add_65[0][0]']
#
#  batch_normalization_86 (BatchN  (None, 150, 40)     160         ['conv1d_86[0][0]']
#  ormalization)
#
#  batch_normalization_119 (Batch  (None, 150, 40)     160         ['conv1d_119[0][0]']
#  Normalization)
#
#  activation_86 (Activation)     (None, 150, 40)      0           ['batch_normalization_86[0][0]']
#
#  activation_119 (Activation)    (None, 150, 40)      0           ['batch_normalization_119[0][0]']
#
#  dropout_46 (Dropout)           (None, 150, 40)      0           ['activation_86[0][0]']
#
#  dropout_65 (Dropout)           (None, 150, 40)      0           ['activation_119[0][0]']
#
#  stochastic_depth_18 (Stochasti  (None, 150, 40)     0           ['dropout_46[0][0]']
#  cDepth)
#
#  stochastic_depth_26 (Stochasti  (None, 150, 40)     0           ['dropout_65[0][0]']
#  cDepth)
#
#  add_47 (Add)                   (None, 150, 40)      0           ['stochastic_depth_18[0][0]',
#                                                                   'dropout_45[0][0]']
#
#  add_66 (Add)                   (None, 150, 40)      0           ['stochastic_depth_26[0][0]',
#                                                                   'dropout_64[0][0]']
#
#  layer_normalization_21 (LayerN  (None, 150, 40)     80          ['add_47[0][0]']
#  ormalization)
#
#  layer_normalization_30 (LayerN  (None, 150, 40)     80          ['add_66[0][0]']
#  ormalization)
#
#  dense_21 (Dense)               (None, 150, 40)      1640        ['layer_normalization_21[0][0]']
#
#  dense_30 (Dense)               (None, 150, 40)      1640        ['layer_normalization_30[0][0]']
#
#  dropout_47 (Dropout)           (None, 150, 40)      0           ['dense_21[0][0]']
#
#  dropout_66 (Dropout)           (None, 150, 40)      0           ['dense_30[0][0]']
#
#  dense_22 (Dense)               (None, 150, 40)      1640        ['dropout_47[0][0]']
#
#  dense_31 (Dense)               (None, 150, 40)      1640        ['dropout_66[0][0]']
#
#  dropout_48 (Dropout)           (None, 150, 40)      0           ['dense_22[0][0]']
#
#  dropout_67 (Dropout)           (None, 150, 40)      0           ['dense_31[0][0]']
#
#  stochastic_depth_19 (Stochasti  (None, 150, 40)     0           ['dropout_48[0][0]']
#  cDepth)
# ...
# 09-16 18:22 [INFO] [EQCCT_Picker] 2014
Z.mseed
# 09-16 18:23 [INFO] [EQCCT_Picker] 2014-04-12T02:36:49.370000Z__2014-04-12T02:38:49.370000Z.mseed
# 09-16 18:23 [INFO] [EQCCT_Picker] 2014-04-12T06:54:09.190000Z__2014-04-12T06:56:09.190000Z.mseed
# 09-16 18:23 [INFO] [EQCCT_Picker] 2014-04-12T07:28:53.370000Z__2014-04-12T07:30:53.370000Z.mseed
# 09-16 18:23 [INFO] [EQCCT_Picker] 2014-04-12T07:31:42.860000Z__2014-04-12T07:33:42.860000Z.mseed

# %%
import pandas as pd
import numpy as np
data = pd.read_csv('./detections2/TOWH_outputs/X_prediction_results.csv', low_memory=False)
data

# %%
import obspy
finalnameall=[]
Parrivalfinal=[]
Pprobfinal=[]

name = (np.unique(data['file_name']))

for u in range(0,len(name)):
    
    exist = np.where(data['file_name']==name[u])[0]
    Parrival = np.array(data['p_arrival_time'][exist]) 
    Pprob = np.array(data['p_probability'][exist])
    
    PprobA = []
    ParrivalA = []
    for ku,zu in zip(Parrival,Pprob):
        if len(str(ku))>4:
            ParrivalA.append(ku)
            PprobA.append(zu)
            
    if len(PprobA)>0:
        #flagind = np.argmax(PprobA)

        flagind = 0
        finalnameall.append(name[u])
        Parrivalfinal.append(ParrivalA[flagind])
        Pprobfinal.append(PprobA[flagind])
        
    else:
        finalnameall.append(name[u])
        Parrivalfinal.append('nan')
        Pprobfinal.append('nan')

# %%
PWaveTime   = np.load(r'./Japan_Catalog_Picks/PWaveTime.npy',allow_pickle=True)
SWaveTime   = np.load(r'./Japan_Catalog_Picks/SWaveTime.npy',allow_pickle=True)
TOWMAGall   = np.load(r'./Japan_Catalog_Picks/TOWMAGall.npy')
TOWDEPTHall = np.load(r'./Japan_Catalog_Picks/TOWDEPTHall.npy')
TOWLATall   = np.load(r'./Japan_Catalog_Picks/TOWLATall.npy')
TOWLONGall  = np.load(r'./Japan_Catalog_Picks/TOWLONGall.npy')
filenameallREAD = np.load(r'./Japan_Catalog_Picks/filenameall.npy')

PCAT=[]
for i in PWaveTime:
    PCAT.append(obspy.UTCDateTime(i))
PCAT = np.array(PCAT)

SCAT=[]
for i in SWaveTime:
    SCAT.append(obspy.UTCDateTime(i))
SCAT = np.array(SCAT)

len(PCAT), len(SCAT)

# %%
samp = 50
PEQ_err = []
miss=[]
mag=[]
dep=[]
filenameallREAD = np.array(filenameallREAD)
finalnameall = np.array(finalnameall)
missname=[]
PEQ_errName=[]
PEQ_errVal=[]
for i in range(len(filenameallREAD)):
    #temp = data['file_name'][i]
    temp = filenameallREAD[i]
    
    try:
        indxPick = np.where(finalnameall==temp)[0]
        PEQ_err.append(PCAT[i]-obspy.UTCDateTime(Parrivalfinal[indxPick[0]]))
        mag.append(TOWMAGall[indxPick])
        dep.append(TOWDEPTHall[indxPick])
        
        zo = PCAT[i]-obspy.UTCDateTime(Parrivalfinal[indxPick[0]])
        if zo>(samp/100):
            PEQ_errName.append(filenameallREAD[i])
            PEQ_errVal.append(zo)
            
    except:
        miss.append(filenameallREAD[i])
        #missname.append(i)
        continue
        
mag = np.array(mag)
dep = np.array(dep)
PEQ_err = np.array(PEQ_err)*100
len(PEQ_err), len(np.where(np.abs(PEQ_err)<=samp)[0]), len(miss)

# %%
countp = []
for g in Parrivalfinal:
    if len(str(g))<10:
        countp.append(g)
len(countp)

# %%
len(np.where(np.abs(PEQ_err)<=samp)[0]) /len(PEQ_err)

# %%
a0 = np.where(np.abs(PEQ_err)<=samp)[0]
np.mean(PEQ_err[a0]/100), np.mean(np.abs(PEQ_err[a0])/100), np.std(PEQ_err[a0]/100)

# %%
#003 (0.015358418017028289, 0.03775885745674265, 0.050380472932146377,  92.64, 92.34)
#006 (0.024432040189785093, 0.04585542841194530, 0.056218194597406401,  91.11, 90.87)

# %%
import matplotlib.pyplot as plt

plt.hist(PEQ_err/100, bins=2000)
plt.xlim([-1,1])
1

# %%
TP = len(np.where(np.abs(PEQ_err)<=samp)[0])
TN = 0
FP = 0
FN = len(miss) + len(np.where(np.abs(PEQ_err)>samp)[0])
R = TP /(TP + FN)
TP+TN+FP+FN, R

# %%
len(PEQ_err) + len(miss)

# %%
import obspy
finalnameall=[]
Sarrivalfinal=[]
Sprobfinal=[]

name = (np.unique(data['file_name']))

for u in range(0,len(name)):
    
    exist = np.where(data['file_name']==name[u])[0]
    Sarrival = np.array(data['s_arrival_time'][exist]) 
    Sprob = np.array(data['s_probability'][exist])
    
    SprobA = []
    SarrivalA = []
    for ku,zu in zip(Sarrival,Sprob):
        if len(str(ku))>4:
            SarrivalA.append(ku)
            SprobA.append(zu)
            
    if len(SprobA)>0:
        #flagind = np.argmax(SprobA)
        flagind = 0
        finalnameall.append(name[u])
        Sarrivalfinal.append(SarrivalA[flagind])
        Sprobfinal.append(SprobA[flagind])
        
    else:
        finalnameall.append(name[u])
        Sarrivalfinal.append('nan')
        Sprobfinal.append('nan')

# %%
counts = []
for g in Sarrivalfinal:
    if len(str(g))<10:
        counts.append(g)
len(counts)

# %%
samp = 50
SEQ_err = []
miss=[]
mag=[]
dep=[]
filenameallREAD = np.array(filenameallREAD)
finalnameall = np.array(finalnameall)
#for i in range(len(finalnameall)):
#    finalnameall[i] = finalnameall[i].replace('_',':')
#    finalnameall[i] = finalnameall[i].replace('::','__')
    

missname=[]
for i in range(len(filenameallREAD)):
    #temp = data['file_name'][i]
    temp = filenameallREAD[i]
    
    try:
        indxPick = np.where(finalnameall==temp)[0]
        SEQ_err.append(SCAT[i]-obspy.UTCDateTime(Sarrivalfinal[indxPick[0]]))
        mag.append(TOWMAGall[indxPick])
        dep.append(TOWDEPTHall[indxPick])
    except:
        miss.append(filenameallREAD[i])
        #missname.append(i)
        continue
        
mag = np.array(mag)
dep = np.array(dep)
SEQ_err = np.array(SEQ_err)*100
len(SEQ_err), len(np.where(np.abs(SEQ_err)<=samp)[0]), len(miss)

# %%
len(np.where(np.abs(SEQ_err)<=samp)[0]) /len(SEQ_err)

# %%
a0 = np.where(np.abs(SEQ_err)<=samp)[0]
np.mean(SEQ_err[a0]/100), np.mean(np.abs(SEQ_err[a0])/100), np.std(SEQ_err[a0]/100)

# %%
import matplotlib.pyplot as plt

plt.hist(SEQ_err/100, bins=2000)
plt.xlim([-1,1])
1

# %%
TP = len(np.where(np.abs(SEQ_err)<=samp)[0])
TN = 0
FP = 0
FN =  len(miss) + len(np.where(np.abs(SEQ_err)>samp)[0])
R = TP /(TP + FN)
TP+TN+FP+FN, R
